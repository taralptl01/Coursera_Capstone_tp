# %% [markdown]
# # Introduction & Business Problem
#
# ## Introduction Section:
# ### Description of the problem and a discussion of the background:
# I have been laid off due to COVID pandemic since April. I was working in one of the Oil and Gas service industry.
# I was unable to land any professional job after actively searching for longer period of time.
# Recently, colleague of mine started pressure washing business and asking me to join /start independent business.
# I have been working on to pursue my data science certification for more than 8 months and thought this would be a great application to apply my skills and knowledge.
# In this report includes neighborhood pressure washing businesses, with the residential neighborhood and business potential.
# The purpose of this project is to get following information.
# 1) How many pressures washing business within 50 miles of sugar land city?
# 2) How many businesses are close withing 10 miles?
# 3) What will be the good location to set up my office.?
#
# ## Description of the data and how it will be used to solve the problem:
# ### Description of the data:
# The following data is required to answer the issue of the problem:
# 1) Collect data of all Pressure and/or Power washing businesses including their name, location, city, with their geodata (latitude and longitude).
# 2) for simplicity, home location defined as startup office location to fetch the data.
# ### How the data will be used to solve the problem
# 1) Use Foursquare and apply folium for visualizing all pressure washing businesses and clustered in groups.
# 2) Observe the locations of the business and predict an appropriate location of the office.
# 3) Visualize the business density respect to residential neighborhoods.
# 4) Find out total numbers of pressure washing businesses within 50 miles.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
from ipykernel import kernelapp as app


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'WQW5YYCTTISIG1VEN4OLRGY1FALY5GCU2HZRUUZJ351FKHDA' # your Foursquare ID
CLIENT_SECRET = 'L4L1AIASMSXBDBYHMXKKMPIIXBEMAN1YOSADLRQNK4HQVJNU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WQW5YYCTTISIG1VEN4OLRGY1FALY5GCU2HZRUUZJ351FKHDA
# CLIENT_SECRET:L4L1AIASMSXBDBYHMXKKMPIIXBEMAN1YOSADLRQNK4HQVJNU

# %% [markdown]
# # Pressure Washing business around home resisdence

# %%
address = '3003 Mast Ct, Sugar Land, TX'# Home address

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 29.57699614285714 -95.60012155102041

# %%
neighborhood_latitude=29.57699614285714
neighborhood_longitude=-95.60012155102041
search_query = 'Power Washing, Pressure Washing'
radius = 80500
print(search_query + ' .... OK!')
# Out:
# Power Washing, Pressure Washing .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WQW5YYCTTISIG1VEN4OLRGY1FALY5GCU2HZRUUZJ351FKHDA&client_secret=L4L1AIASMSXBDBYHMXKKMPIIXBEMAN1YOSADLRQNK4HQVJNU&ll=29.57699614285714,-95.60012155102041&v=20180605&query=Power Washing, Pressure Washing&radius=80500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fa85494418d9541e702fec5'},
#  'response': {'venues': [{'id': '5805babad67cdd5c112078c6',
#     'name': 'Mudcutters Power Washing',
#     'location': {'address': '3536 Highway 6 Ste B # 266',
#      'lat': 29.589027182966714,
#      'lng': -95.59851050376892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.589027182966714,
#        'lng': -95.59851050376892}],
#      'distance': 1348,
#      'postalCode': '77478',
#      'cc': 'US',
#      'city': 'Sugar Land',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3536 Highway 6 Ste B # 266',
#       'Sugar Land, TX 77478',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1d',
#       'name': 'Dry Cleaner',
#       'pluralName': 'Dry Cleaners',
#       'shortName': 'Dry Cleaner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/drycleaner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5a1ba30ba4ba7c160b0eb8c1',
#     'name': 'Pressure Washing Sugar Land',
#     'location': {'address': '2315 Old Mill Rd #7',
#      'lat': 29.59023094177246,
#      'lng': -95.59476470947266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.59023094177246,
#        'lng': -95.59476470947266}],
#      'distance': 1561,
#      'postalCode': '77478',
#      'cc': 'US',
#      'city': 'Sugar Land',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2315 Old Mill Rd #7',
#       'Sugar Land, TX 77478',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '574763e3498ee4b7a4a83258',
#     'name': 'Made Affordable Pressure Washing Services',
#     'location': {'address': '16114 Bowridge Ln',
#      'lat': 29.594069750772274,
#      'lng': -95.47923803329468,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.594069750772274,
#        'lng': -95.47923803329468}],
#      'distance': 11855,
#      'postalCode': '77053',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['16114 Bowridge Ln',
#       'Houston, TX 77053',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '568c64c0498e9a9c93d566c9',
#     'name': 'HCC Pressure Washing, LLC',
#     'location': {'address': '11631 Cedar Creek Dr',
#      'crossStreet': 'Briar Forest',
#      'lat': 29.7471460547063,
#      'lng': -95.58345258235931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.7471460547063,
#        'lng': -95.58345258235931}],
#      'distance': 19009,
#      'postalCode': '77077',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['11631 Cedar Creek Dr (Briar Forest)',
#       'Houston, TX 77077',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '180409982'},
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '579bf90b498ebfdb3858f351',
#     'name': 'Mudcutters Power Washing Sugar Land TX',
#     'location': {'address': '20403 University Blvd',
#      'crossStreet': 'Ste 108',
#      'lat': 29.612241744995117,
#      'lng': -95.64065551757812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.612241744995117,
#        'lng': -95.64065551757812}],
#      'distance': 5548,
#      'postalCode': '77478',
#      'cc': 'US',
#      'city': 'Sugar Land',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['20403 University Blvd (Ste 108)',
#       'Sugar Land, TX 77478',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5a72b6f40e5da8552360c7e5',
#     'name': 'Best Power Washing Co.',
#     'location': {'address': '4623 Schiller Park Ln',
#      'lat': 29.58467,
#      'lng': -95.69169,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.58467,
#        'lng': -95.69169}],
#      'distance': 8905,
#      'postalCode': '77479',
#      'cc': 'US',
#      'city': 'Sugar Land',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4623 Schiller Park Ln',
#       'Sugar Land, TX 77479',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '55863c13498e2138f0c871ca',
#     'name': "Petty's Mobile RV Detailing and Pressure Washing",
#     'location': {'address': '10515 Southwest Fwy Ste G001',
#      'lat': 29.66331672668457,
#      'lng': -95.55241394042969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.66331672668457,
#        'lng': -95.55241394042969}],
#      'distance': 10660,
#      'postalCode': '77074',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10515 Southwest Fwy Ste G001',
#       'Houston, TX 77074',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '55e6929c498e507d78cd2b31',
#     'name': 'Revitalize Pressure Washing',
#     'location': {'address': '15183 S Post Oak Rd',
#      'lat': 29.606210708618164,
#      'lng': -95.46419525146484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.606210708618164,
#        'lng': -95.46419525146484}],
#      'distance': 13553,
#      'postalCode': '77053',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['15183 S Post Oak Rd',
#       'Houston, TX 77053',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5e96337e68ee280007e39506',
#     'name': 'Still Waters Power Washing LLC',
#     'location': {'address': '503 FM 359 Rd Ste 130 # 125',
#      'lat': 29.6020409,
#      'lng': -95.743394,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.6020409,
#        'lng': -95.743394}],
#      'distance': 14146,
#      'postalCode': '77406',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['503 FM 359 Rd Ste 130 # 125',
#       'Richmond, TX 77406',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '55617d3e498ec487d4d0e442',
#     'name': 'Houston Pressure Washing',
#     'location': {'address': '7705 McHard Rd # 104-C',
#      'lat': 29.58282470703125,
#      'lng': -95.4505844116211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.58282470703125,
#        'lng': -95.4505844116211}],
#      'distance': 14491,
#      'postalCode': '77053',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['7705 McHard Rd # 104-C',
#       'Houston, TX 77053',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '59e55c7d829b0c3c8984ef17',
#     'name': 'Your Quality Pressure Washing',
#     'location': {'address': '7027 Camino Verde Drive',
#      'lat': 29.7025912,
#      'lng': -95.66964569999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.7025912,
#        'lng': -95.66964569999999}],
#      'distance': 15515,
#      'postalCode': '77083',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['7027 Camino Verde Drive',
#       'Houston, TX 77083',
#       'United States']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '51a5caebabd84d4af28e3c75',
#     'name': '1st Power Washing',
#     'location': {'address': '7520 Hillcroft St',
#      'lat': 29.695317827372236,
#      'lng': -95.49248278141022,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.695317827372236,
#        'lng': -95.49248278141022}],
#      'distance': 16791,
#      'postalCode': '77081',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['7520 Hillcroft St',
#       'Houston, TX 77081',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5b8058eb35f983002cfd84c6',
#     'name': 'Pressure Washing Maintenance',
#     'location': {'address': '11807 Westheimer Road Suite 550',
#      'lat': 29.7362851,
#      'lng': -95.58756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.7362851,
#        'lng': -95.58756}],
#      'distance': 17773,
#      'postalCode': '77077',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['11807 Westheimer Road Suite 550',
#       'Houston, TX 77077',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5820569308396928a3684a68',
#     'name': 'Ultra Pressure Washing',
#     'location': {'address': 'Houston',
#      'lat': 29.730266332880532,
#      'lng': -95.59884693797358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.730266332880532,
#        'lng': -95.59884693797358}],
#      'distance': 17062,
#      'postalCode': '77082',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Houston', 'Houston, TX 77082', 'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '516ce01439505ffd38d04819',
#     'name': 'Power Washing Houston',
#     'location': {'address': '1004 Prairie #300',
#      'lat': 29.76027938368445,
#      'lng': -95.3614354133606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.76027938368445,
#        'lng': -95.3614354133606}],
#      'distance': 30810,
#      'postalCode': '77002',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['1004 Prairie #300',
#       'Houston, TX 77002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5411212b498edd6d452ad4f1',
#     'name': 'Genn-USA Pressure Washing',
#     'location': {'address': '2113 County Road 124',
#      'lat': 29.526840209960938,
#      'lng': -95.23767852783203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.526840209960938,
#        'lng': -95.23767852783203}],
#      'distance': 35539,
#      'postalCode': '77581',
#      'isFuzzed': True,
#      'isServiceAreaBusiness': True,
#      'cc': 'US',
#      'neighborhood': 'Lexington Colony, Missouri City, TX',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2113 County Road 124',
#       'Pearland, TX 77581',
#       'United States']},
#     'categories': [{'id': '5454144b498ec1f095bff2f2',
#       'name': 'Construction & Landscaping',
#       'pluralName': 'Construction & Landscaping',
#       'shortName': 'Construction',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '94560160'},
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5a75128d18d43b7c9069a7af',
#     'name': 'Xtreme Kleen Pressure Washing',
#     'location': {'address': '5233 Bellaire Blvd Ste B-123',
#      'lat': 29.705114364624023,
#      'lng': -95.47185516357422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.705114364624023,
#        'lng': -95.47185516357422}],
#      'distance': 18905,
#      'postalCode': '77401',
#      'cc': 'US',
#      'city': 'Bellaire',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['5233 Bellaire Blvd Ste B-123',
#       'Bellaire, TX 77401',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '55c8d3fc498e1fc7e28cee2f',
#     'name': 'Webb’s Pressure Washing Service',
#     'location': {'lat': 29.643248382970572,
#      'lng': -95.79756259918213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.643248382970572,
#        'lng': -95.79756259918213}],
#      'distance': 20482,
#      'postalCode': '77406',
#      'cc': 'US',
#      'city': 'Richmond',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Richmond, TX 77406', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'shortName': 'Laundry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5d398d69d56d8b0007354bdf',
#     'name': 'Quality Pressure Washing of Houston',
#     'location': {'address': '14135 Heatherfield Dr',
#      'lat': 29.76101,
#      'lng': -95.59089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.76101,
#        'lng': -95.59089}],
#      'distance': 20503,
#      'postalCode': '77079',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['14135 Heatherfield Dr',
#       'Houston, TX 77079',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5e9ac0960606090008f7fb35',
#     'name': 'Legacy Power Washing',
#     'location': {'address': '7827 Harms Rd',
#      'lat': 29.76734,
#      'lng': -95.623389,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.76734,
#        'lng': -95.623389}],
#      'distance': 21308,
#      'postalCode': '77041',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['7827 Harms Rd',
#       'Houston, TX 77041',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '4f68db876d86f87117a11be7',
#     'name': 'South Texas Pressure Washing',
#     'location': {'address': '3040 Farm to Market 518',
#      'crossStreet': 'at SH 288',
#      'lat': 29.555539728391334,
#      'lng': -95.38654088973999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.555539728391334,
#        'lng': -95.38654088973999}],
#      'distance': 20817,
#      'postalCode': '77581',
#      'cc': 'US',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3040 Farm to Market 518 (at SH 288)',
#       'Pearland, TX 77581',
#       'United States']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5a1b9979dab4b138e580ca7c',
#     'name': 'Pressure Washing Pearland',
#     'location': {'address': '307 Broadway St. Ste 248',
#      'lat': 29.556596659969415,
#      'lng': -95.36824151873589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.556596659969415,
#        'lng': -95.36824151873589}],
#      'distance': 22565,
#      'postalCode': '77584',
#      'cc': 'US',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['307 Broadway St. Ste 248',
#       'Pearland, TX 77584',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '52c34038498e73bc8537e021',
#     'name': 'Pressure Washing America, LLC',
#     'location': {'address': '19506 Cardiff Park Ln',
#      'lat': 29.76601791381836,
#      'lng': -95.70825958251953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.76601791381836,
#        'lng': -95.70825958251953}],
#      'distance': 23497,
#      'postalCode': '77094',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['19506 Cardiff Park Ln',
#       'Houston, TX 77094',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '78522686'},
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '574f050e498ef9f34a1d6539',
#     'name': 'Carlson Precision Pressure Washing Services, LLC',
#     'location': {'address': '3114 Aspen Ln',
#      'lat': 29.527527000000003,
#      'lng': -95.370866,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.527527000000003,
#        'lng': -95.370866},
#       {'label': 'entrance', 'lat': 29.527611, 'lng': -95.370899}],
#      'distance': 22873,
#      'postalCode': '77578',
#      'cc': 'US',
#      'city': 'Manvel',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3114 Aspen Ln',
#       'Manvel, TX 77578',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '579bf102498ee0d575fab4b7',
#     'name': 'Mudcutters Power Washing Katy TX',
#     'location': {'address': '23501 Cinco Ranch Blvd Ste H120 # 167B',
#      'crossStreet': 'Ste H120 #167B',
#      'lat': 29.74283310401812,
#      'lng': -95.77627927064894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.74283310401812,
#        'lng': -95.77627927064894}],
#      'distance': 25123,
#      'postalCode': '77494',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['23501 Cinco Ranch Blvd Ste H120 # 167B (Ste H120 #167B)',
#       'Katy, TX 77494',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5f1748b6292d9e79cae9f1f6',
#     'name': 'Big Bros’ Pressure Washing',
#     'location': {'address': '4018 Avenue B',
#      'lat': 29.793005,
#      'lng': -95.953337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.793005,
#        'lng': -95.953337}],
#      'distance': 41773,
#      'postalCode': '77423',
#      'cc': 'US',
#      'city': 'Brookshire',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4018 Avenue B',
#       'Brookshire, TX 77423',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5826de523398744fe49942cc',
#     'name': 'Houston Pressure Washing HQ',
#     'location': {'address': '10939 Shadow Wood Dr',
#      'lat': 29.804397583007812,
#      'lng': -95.57183074951172,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.804397583007812,
#        'lng': -95.57183074951172}],
#      'distance': 25461,
#      'postalCode': '77043',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10939 Shadow Wood Dr',
#       'Houston, TX 77043',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '56a9bd22498ead151cd958a0',
#     'name': 'Pressure Washing Katy',
#     'location': {'address': '26707 Henson Falls Dr',
#      'lat': 29.699424743652344,
#      'lng': -95.83967590332031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.699424743652344,
#        'lng': -95.83967590332031}],
#      'distance': 26887,
#      'postalCode': '77494',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['26707 Henson Falls Dr',
#       'Katy, TX 77494',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1d',
#       'name': 'Dry Cleaner',
#       'pluralName': 'Dry Cleaners',
#       'shortName': 'Dry Cleaner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/drycleaner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5d555d4f58369d0008dca921',
#     'name': 'Sunny Pressure Washing',
#     'location': {'address': '10551 Emnora Ln',
#      'lat': 29.8148158,
#      'lng': -95.5564367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.8148158,
#        'lng': -95.5564367}],
#      'distance': 26808,
#      'postalCode': '77043',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10551 Emnora Ln',
#       'Houston, TX 77043',
#       'United States']},
#     'categories': [{'id': '4f2a23984b9023bd5841ed2c',
#       'name': 'Moving Target',
#       'pluralName': 'Moving Targets',
#       'shortName': 'Moving Target',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5a96a02006fb6069ef4aed57',
#     'name': 'Sunny Pressure Washing',
#     'location': {'address': '8716 Long Point Rd Ste 310',
#      'lat': 29.803781509399414,
#      'lng': -95.50353240966797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.803781509399414,
#        'lng': -95.50353240966797}],
#      'distance': 26918,
#      'postalCode': '77055',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['8716 Long Point Rd Ste 310',
#       'Houston, TX 77055',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5b20cb038fb09e002c0d002d',
#     'name': 'LSL Pressure Washing Services LLC',
#     'location': {'address': '6220 Fairdale Ln',
#      'lat': 29.731374,
#      'lng': -95.377295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.731374,
#        'lng': -95.377295},
#       {'label': 'entrance', 'lat': 29.731393, 'lng': -95.377331}],
#      'distance': 27567,
#      'postalCode': '77057',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['6220 Fairdale Ln',
#       'Houston, TX 77057',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5805f26838fa3a1b06049a0a',
#     'name': 'Mudcutters Power Washing',
#     'location': {'address': '23501 Cinco Ranch Blvd Ste H120 # 167B',
#      'lat': 29.73917207374698,
#      'lng': -95.83224892616272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.73917207374698,
#        'lng': -95.83224892616272}],
#      'distance': 28812,
#      'postalCode': '77494',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['23501 Cinco Ranch Blvd Ste H120 # 167B',
#       'Katy, TX 77494',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5e293bcfc67c9c0008424fbf',
#     'name': 'Pressure Washing America, LLC',
#     'location': {'address': '19506 Cardiff Park Ln',
#      'lat': 29.759068581400214,
#      'lng': -95.3659039735794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.759068581400214,
#        'lng': -95.3659039735794}],
#      'distance': 30398,
#      'postalCode': '77094',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['19506 Cardiff Park Ln',
#       'Houston, TX 77094',
#       'United States']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '533bb1b411d26b68ddf3a9de',
#     'name': 'Pressure Washing',
#     'location': {'address': '2100 Pearland Ave',
#      'lat': 29.56384555936571,
#      'lng': -95.28646230697632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.56384555936571,
#        'lng': -95.28646230697632}],
#      'distance': 30403,
#      'postalCode': '77584',
#      'cc': 'US',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2100 Pearland Ave',
#       'Pearland, TX 77584',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5f33a4e848c64a2e52cb87be',
#     'name': 'Lucas Painting and Power Washing',
#     'location': {'address': 'Houston',
#      'lat': 29.757671483662353,
#      'lng': -95.36785125732422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.757671483662353,
#        'lng': -95.36785125732422}],
#      'distance': 30154,
#      'postalCode': '77053',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Houston', 'Houston, TX 77053', 'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '556f8672498efe5cad2aee89',
#     'name': 'A Pro Pressure Washing',
#     'location': {'lat': 29.76214212786138,
#      'lng': -95.36270141601562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.76214212786138,
#        'lng': -95.36270141601562}],
#      'distance': 30856,
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Houston, TX', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5c25a36d0802d4002c75b757',
#     'name': "Prescott's Pressure Washing",
#     'location': {'address': '1134 Robert St',
#      'lat': 29.5927324,
#      'lng': -95.28119889999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.5927324,
#        'lng': -95.28119889999999},
#       {'label': 'entrance', 'lat': 29.592709, 'lng': -95.281136}],
#      'distance': 30923,
#      'postalCode': '77581',
#      'cc': 'US',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['1134 Robert St',
#       'Pearland, TX 77581',
#       'United States']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '59252279db2aeb6a89acfd54',
#     'name': 'Medina Mobile Power Washing',
#     'location': {'lat': 29.761154877760564,
#      'lng': -95.36706805229186,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.761154877760564,
#        'lng': -95.36706805229186}],
#      'distance': 30469,
#      'postalCode': '77065',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Houston, TX 77065', 'United States']},
#     'categories': [{'id': '4f04ae1f2fb6e1c99f3db0ba',
#       'name': 'Car Wash',
#       'pluralName': 'Car Washes',
#       'shortName': 'Car Washes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/carwash_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '553f2134498ee911562b258a',
#     'name': 'Pearland Pressure Washing',
#     'location': {'address': '3221 Broadway St # 48-A',
#      'lat': 29.559329986572266,
#      'lng': -95.27146911621094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.559329986572266,
#        'lng': -95.27146911621094}],
#      'distance': 31881,
#      'postalCode': '77581',
#      'cc': 'US',
#      'city': 'Pearland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3221 Broadway St # 48-A',
#       'Pearland, TX 77581',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '51254188c84c02244b359ad4',
#     'name': 'SuperSoakers Pressure Washing',
#     'location': {'lat': 29.83116960802032,
#      'lng': -95.73724508285522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.83116960802032,
#        'lng': -95.73724508285522}],
#      'distance': 31246,
#      'postalCode': '77449',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['Katy, TX 77449', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5c1c883ca87921002c5b100e',
#     'name': 'Blue Trust Pressure Washing',
#     'location': {'address': '316 Bob St',
#      'lat': 29.744714000000002,
#      'lng': -95.330158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.744714000000002,
#        'lng': -95.330158}],
#      'distance': 32101,
#      'postalCode': '77011',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['316 Bob St', 'Houston, TX 77011', 'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '599b0b45aa6c9556c7baa483',
#     'name': 'Precision Pressure Washing Services',
#     'location': {'address': '2512 Village Circle Dr',
#      'crossStreet': 'Lilac',
#      'lat': 29.810021386756326,
#      'lng': -95.81929922103882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.810021386756326,
#        'lng': -95.81929922103882}],
#      'distance': 33497,
#      'postalCode': '77493',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2512 Village Circle Dr (Lilac)',
#       'Katy, TX 77493',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '561b0d10498e86b30fccd3ce',
#     'name': "Tino's Window Cleaning & Pressure Washing Service",
#     'location': {'address': '5920 N Sam Houston Pkwy E',
#      'lat': 29.938547999999997,
#      'lng': -95.301328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.938547999999997,
#        'lng': -95.301328},
#       {'label': 'entrance', 'lat': 29.939124, 'lng': -95.301336}],
#      'distance': 49534,
#      'postalCode': '77396',
#      'cc': 'US',
#      'city': 'Humble',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['5920 N Sam Houston Pkwy E',
#       'Humble, TX 77396',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5efb92df829d9600082697df',
#     'name': 'Can Do Pressure Washing',
#     'location': {'address': '5427 Winford Dr',
#      'lat': 29.850141,
#      'lng': -95.726148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.850141,
#        'lng': -95.726148}],
#      'distance': 32756,
#      'postalCode': '77449',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['5427 Winford Dr',
#       'Katy, TX 77449',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5735f4e3498e8df1c95fda07',
#     'name': "5 J's Power Washing Service",
#     'location': {'address': '8942 Edgebrook St',
#      'lat': 29.639771999999997,
#      'lng': -95.25682900000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.639771999999997,
#        'lng': -95.25682900000001},
#       {'label': 'entrance', 'lat': 29.63984, 'lng': -95.256845}],
#      'distance': 33951,
#      'postalCode': '77075',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['8942 Edgebrook St',
#       'Houston, TX 77075',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5bc4756ce55d8b002cbc84e7',
#     'name': 'HCC Pressure Washing, LLC',
#     'location': {'address': '18403 Willow Moss Dr',
#      'lat': 29.871798,
#      'lng': -95.689476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.871798,
#        'lng': -95.689476}],
#      'distance': 33934,
#      'postalCode': '77449',
#      'cc': 'US',
#      'city': 'Katy',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['18403 Willow Moss Dr',
#       'Katy, TX 77449',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '56876123498ecea147026b79',
#     'name': 'LB Power Washing',
#     'location': {'address': '15817 Jersey Dr',
#      'lat': 29.887786,
#      'lng': -95.56132500000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.887786,
#        'lng': -95.56132500000001}],
#      'distance': 34799,
#      'postalCode': '77040',
#      'cc': 'US',
#      'city': 'Jersey Village',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['15817 Jersey Dr',
#       'Jersey Village, TX 77040',
#       'United States']},
#     'categories': [{'id': '4f04ae1f2fb6e1c99f3db0ba',
#       'name': 'Car Wash',
#       'pluralName': 'Car Washes',
#       'shortName': 'Car Washes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/carwash_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '150425875'},
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '58254d2e1dbf6c7dd8068205',
#     'name': 'Fulshear Pressure Washing',
#     'location': {'address': '4515 Wickby St',
#      'lat': 29.66514,
#      'lng': -95.94352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.66514,
#        'lng': -95.94352}],
#      'distance': 34649,
#      'postalCode': '77441',
#      'cc': 'US',
#      'city': 'Fulshear',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4515 Wickby St',
#       'Fulshear, TX 77441',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06375d81259',
#       'name': 'Professional & Other Places',
#       'pluralName': 'Professional & Other Places',
#       'shortName': 'Professional',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '5c75b700a4ba7c002ca8fc95',
#     'name': 'H-Town Pressure Washing Services',
#     'location': {'address': '10110 Kirkplum Dr',
#      'lat': 29.5896873,
#      'lng': -95.2371291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.5896873,
#        'lng': -95.2371291}],
#      'distance': 35168,
#      'postalCode': '77089',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['10110 Kirkplum Dr',
#       'Houston, TX 77089',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False},
#    {'id': '580e598438fad8dc16e43995',
#     'name': 'HotShot Pressure Washing',
#     'location': {'address': '11018 Sagemorgan Dr',
#      'lat': 29.586240768432617,
#      'lng': -95.23531341552734,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 29.586288,
#        'lng': -95.235224},
#       {'label': 'display',
#        'lat': 29.586240768432617,
#        'lng': -95.23531341552734}],
#      'distance': 35331,
#      'postalCode': '77089',
#      'cc': 'US',
#      'city': 'Houston',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['11018 Sagemorgan Dr',
#       'Houston, TX 77089',
#       'United States']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604867220',
#     'hasPerk': False}]}}

# %%
## Thanks!!
